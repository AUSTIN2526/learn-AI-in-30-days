# %%
import numpy as np
import matplotlib.pyplot as plt
import math

class Perceptron:
    def model(self, x):
        self.b = np.dot(self.w, x) / (np.linalg.norm(self.w) * np.linalg.norm(x))
        self.b = math.acos(self.b)
        
        return np.dot(self.w, x) + self.b > 0  
    
    def fit(self, X, Y, epochs = 100, lr = 0.05):
        self.w = np.random.uniform(-0.5, 0.5, X.shape[1])
        self.result = {'acc':[],
                       'w':[],
                       'b':[],
                       'epoch':[]
        }

        for i in range(epochs):
            acc = 0
            for x, y in zip(X, Y):
                y_pred = self.model(x)
                if y == 1 and not y_pred:
                    self.w += lr * x
                elif y == 0 and y_pred:
                    self.w -= lr * x
                else:
                    acc+=1
            self.result['epoch'].append(i)
            self.result['acc'].append(acc/len(X))
            self.result['w'].append(self.w)
            self.result['b'].append(self.b)

            #全部預測成功中斷程式
            if acc / len(X) ==1:
                break
            
                    
    def show(self, title):
        plt.plot(self.result['acc'])
        plt.title(title)
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.ylim([0, 1])
        plt.show()
        for i in range(len(self.result['acc'])): \
            print(f"Epoch:{self.result['epoch'][i]}\
 Wight:{self.result['w'][i]}\
 θ:{self.result['b'][i]}\
 Acc:{self.result['acc'][i]}\
            ")
           

    def predict(self,X):
        return [self.model(x) for x in X]

# %%
AND_model = Perceptron()
OR_model =  Perceptron()
XOR_model = Perceptron()

AND_x_train = np.array([[0,0],[0,1],[1,0],[1,1]])
AND_y_train = np.array([0,0,0,1])
AND_x_test = np.array([[0,1],[1,1],[0,0],[1,0]])

OR_x_train = np.array([[0,0],[0,1],[1,0],[1,1]])
OR_y_train = np.array([0,1,1,1])
OR_x_test = np.array([[0,1],[1,1],[0,0],[1,0]])


XOR_x_train = np.array([[0,0],[0,1],[1,0],[1,1]])
XOR_y_train = np.array([0,1,1,0])
XOR_x_test = np.array([[0,1],[1,1],[0,0],[1,0]])


AND_model.fit(AND_x_train, AND_y_train)
OR_model.fit(OR_x_train, OR_y_train)
XOR_model.fit(XOR_x_train, XOR_y_train)
# Out:
# c:\users\austin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys

# %%
AND_model.show('AND')
OR_model.show('OR')
XOR_model.show('XOR')
# Out:
# Epoch:0 Wight:[-1.5924713  -1.45332743] θ:0.18244023346240412 Acc:0.5
# Epoch:1 Wight:[-1.5924713  -1.45332743] θ:0.20956980826137345 Acc:0.5
# Epoch:2 Wight:[-1.5924713  -1.45332743] θ:0.24598640938116517 Acc:0.5
# Epoch:3 Wight:[-1.5924713  -1.45332743] θ:0.29727086088730453 Acc:0.5
# Epoch:4 Wight:[-1.5924713  -1.45332743] θ:0.37431739635486855 Acc:0.5
# Epoch:5 Wight:[-1.5924713  -1.45332743] θ:0.5008269752517693 Acc:0.5
# Epoch:6 Wight:[-1.5924713  -1.45332743] θ:0.7341131826640608 Acc:0.5
# Epoch:7 Wight:[-1.5924713  -1.45332743] θ:1.1993447742529508 Acc:0.5
# Epoch:8 Wight:[-1.5924713  -1.45332743] θ:1.8887740897883 Acc:0.5
# Epoch:9 Wight:[-1.5924713  -1.45332743] θ:2.3795453412216467 Acc:0.5
# Epoch:10 Wight:[-1.5924713  -1.45332743] θ:2.626481287810533 Acc:0.5
Wight:[-1.5924713  -1.45332743] θ:3.097389815537147 Acc:0.25
# Epoch:99 Wight:[-1.5924713  -1.45332743] θ:3.097389815537147 Acc:0.25
# Epoch:0 Wight:[ 0.30972337 -0.05510178] θ:0.9614625062603888 Acc:1.0
# Epoch:0 Wight:[-1.81845354 -1.11979071] θ:1.4826341070954834 Acc:0.75
# Epoch:1 Wight:[-1.81845354 -1.11979071] θ:1.6254809601926623 Acc:0.75
# Epoch:2 Wight:[-1.81845354 -1.11979071] θ:1.7661427471266842 Acc:0.75
# Epoch:3 Wight:[-1.81845354 -1.11979071] θ:1.8994312267904858 Acc:0.75
# Epoch:4 Wight:[-1.81845354 -1.11979071] θ:2.0216682331286235 Acc:0.75
# Epoch:5 Wight:[-1.81845354 -1.11979071] θ:2.131020189527698 Acc:0.75
# Epoch:6 Wight:[-1.81845354 -1.11979071] θ:2.2272210844135527 Acc:0.75
# Epoch:7 Wight:[-1.81845354 -1.11979071] θ:2.311032413916847 Acc:0.75
# Epoch:8 Wight:[-1.81845354 -1.11979071] θ:2.383733787286465 Acc:0.75
# Epoch:9 Wight:[-1.81845354 -1.11979071] θ:2.4467657040964026 Acc:0.75
# Epoch:10 Wight:[-1.81845354 -1.11979071] θ:2.501524860020975 Acc:0.75
# Epoch:11 Wight:[-1.81845354 -1.11979071] θ:2.5492683251197352 Acc:0.75
# Epoch:12 Wight:[-1.81845354 -1.11979071] θ:2.59108240878943 Acc:0.75
# Epoch:13 Wight:[-1.81845354 -1.11979071] θ:2.627884909241204 Acc:0.75
# Epoch:14 Wight:[-1.81845354 -1.11979071] θ:2.660442012769364 Acc:0.75
# Epoch:15 Wight:[-1.81845354 -1.11979071] θ:2.6893898185293215 Acc:0.75
# Epoch:16 Wight:[-1.81845354 -1.11979071] θ:2.7152556519832083 Acc:0.75
# Epoch:17 Wight:[-1.81845354 -1.11979071] θ:2.7384771452634697 Acc:0.75
# Epoch:18 Wight:[-1.81845354 -1.11979071] θ:2.759418479684699 Acc:0.75
# Epoch:19 Wight:[-1.81845354 -1.11979071] θ:2.7783838405658696 Acc:0.75
# Epoch:20 Wight:[-1.81845354 -1.11979071] θ:2.7956283975578704 Acc:0.75
# Epoch:21 Wight:[-1.81845354 -1.11979071] θ:2.811367196484989 Acc:0.75
# Epoch:22 Wight:[-1.81845354 -1.11979071] θ:2.8257823362172583 Acc:0.75
# Epoch:23 Wight:[-1.81845354 -1.11979071] θ:2.839028758624952 Acc:0.75
# Epoch:24 Wight:[-1.81845354 -1.11979071] θ:2.851238926037843 Acc:0.75
# Epoch:25 Wight:[-1.81845354 -1.11979071] θ:2.8625266096966384 Acc:0.75
# Epoch:26 Wight:[-1.81845354 -1.11979071] θ:2.872989968466429 Acc:0.75
# Epoch:27 Wight:[-1.81845354 -1.11979071] θ:2.8827140604222468 Acc:0.75
# Epoch:28 Wight:[-1.81845354 -1.11979071] θ:2.891772900294307 Acc:0.75
# Epoch:29 Wight:[-1.81845354 -1.11979071] θ:2.900231152174669 Acc:0.75
# Epoch:30 Wight:[-1.81845354 -1.11979071] θ:2.9081455282624593 Acc:1.0

# %%
#input 00 11 00 10
print(AND_model.predict(AND_x_test))
print(OR_model.predict(OR_x_test))

#Error
print(XOR_model.predict(XOR_x_test))
# Out:
# [True, True, False, True]
# [True, True, False, True]
# [True, False, False, True]
# c:\users\austin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
